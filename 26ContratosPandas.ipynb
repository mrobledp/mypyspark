# %% [markdown]
# ## Lee los contratos sin fecha del parquet a ver qué puedo hacer desde Jupyter

# %%
import pandas as pd

df = pd.read_parquet("./datos/fakeContractsSinFechas.parquet", engine='fastparquet')
print(df.shape)
print(df.columns)
print(df.loc[0])

#df = df.sort_values(by=['ctId', 'fecRef'])

for i in df.index:
    print(df['ctId'][i]+'-'+df['fecRef'][i])
    if i > 100: break
# Out:
# (1276940, 5)
# Index(['ctId', 'fecRef', 'dato', 'saldo', 'proc'], dtype='object')
# ctId                                      CT0001123484
# fecRef                                      2021-06-21
# dato      Dato del contrato CT0001123484 en 2021-06-21
# saldo                                            47900
# proc                                            CT0001
# Name: 0, dtype: object
# CT0001123484-2021-06-21
# CT0001123484-2021-08-19
# CT0001123484-2021-04-18
# CT0001123484-2020-11-21
# CT0001123484-2021-04-01
# CT0001123484-2021-04-09
# CT0001123484-2021-07-20
# CT0001123484-2020-08-08
# CT0001123484-2021-08-04
# CT0001123515-2021-06-06
# CT0001123515-2021-04-28
# CT0001123515-2020-04-02
# CT0001123515-2020-03-28
# CT0001123515-2021-02-09
# CT0001123515-2021-06-12
# CT0001123515-2021-03-15
# CT0001123515-2021-11-09
# CT0001123515-2021-02-18
# CT0001123515-2021-05-13
# CT0001123515-2020-05-08
# CT0001123556-2020-04-09
# CT0001123556-2021-07-03
# CT0001123556-2021-02-23
# ...
