# %% [markdown]
# ### Lectura de los parquet de contratos partición a partición

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.conf import SparkConf

conf = (SparkConf().set("spark.executor.memory", "6g")
                    .set("spark.executor.cores", "3")
                    .set("spark.executor.instances", "2")
                    .set("spark.eventLog.enabled", "true"))
spark = SparkSession.builder.master("spark://spark-master:7077").appName("ContratosReadParquetPP").config(conf=conf).getOrCreate()
spark
# Out:
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/11/06 18:32:31 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://b3a90b51a42d:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://spark-master:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>ContratosReadParquetPP</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import time
print ('Inicio: '+time.strftime("%c"))
inicio = time.perf_counter()
# Out:
# Inicio: Sun Nov  6 18:32:33 2022

# %%
#spark job monitoring
from pyspark.sql.types import StructType
from pyspark.sql.types import StringType,BooleanType,DateType,IntegerType
from pyspark.sql.functions import sum, col, desc
import pyspark.sql.functions as F
from pyspark.sql import Window

esquema = StructType() \
      .add("ctId",StringType(),True) \
      .add("fecRef",StringType(),True) \
      .add("dato",StringType(),True) \
      .add("saldo",IntegerType(),True) \
      .add("proc",StringType(),True) \
      .add("fechIni",StringType(),True) \
      .add("fechFin",StringType(),True)

for i in range(1, 16):
    inicioP = time.perf_counter()
    if i < 10: proc = 'CT000'+str(i)
    else:      proc = 'CT00'+str(i)

    print ('Tratando partición '+proc)
    
    df = spark.read.option("mergeSchema", True).option("schema", "esquema").option("basePath", "file:///opt/workspace/datos/contratosFecINIFIN.parquet/")\
               .format("parquet").load(['./datos/contratosFecINIFIN.parquet/proc='+proc])
    
    if i == 1:df.printSchema()
    print(df.count())
    df.show(10)
    print ('Fin lectura partición: '+time.strftime("%c"))
    final = time.perf_counter()
    print(f'Hecho en {round(final - inicioP, 4)} segundo(s)')

final = time.perf_counter()
print(f'TOTAL hecho en {round(final - inicio, 4)} segundo(s)')
# Out:
# Tratando partición CT0001
# root
#  |-- ctId: string (nullable = true)
#  |-- fecRef: string (nullable = true)
#  |-- dato: string (nullable = true)
#  |-- saldo: integer (nullable = true)
#  |-- fechIni: string (nullable = true)
#  |-- fechFin: string (nullable = true)
#  |-- proc: string (nullable = true)
# 79285
# +------------+----------+--------------------+-----+----------+----------+------+
# |        ctId|    fecRef|                dato|saldo|   fechIni|   fechFin|  proc|
# +------------+----------+--------------------+-----+----------+----------+------+
# |CT0001123556|2020-03-19|Dato del contrato...| 6800|2020-03-19|2020-04-09|CT0001|
# |CT0001123556|2020-04-09|Dato del contrato...| 1200|2020-04-09|2020-07-24|CT0001|
# |CT0001123556|2020-07-24|Dato del contrato...|26800|2020-07-24|2020-12-19|CT0001|
# |CT0001123556|2020-12-19|Dato del contrato...| 9000|2020-12-19|2021-02-02|CT0001|
# |CT0001123556|2021-02-02|Dato del contrato...|45500|2021-02-02|2021-02-15|CT0001|
# |CT0001123556|2021-02-15|Dato del contrato...|92900|2021-02-15|2021-02-23|CT0001|
# |CT0001123556|2021-02-23|Dato del contrato...| 6200|2021-02-23|2021-05-10|CT0001|
# |CT0001123556|2021-05-10|Dato del contrato...| 7800|2021-05-10|2021-07-03|CT0001|
# |CT0001123556|2021-07-03|Dato del contrato...|24900|2021-07-03|2021-07-31|CT0001|
# |CT0001123556|2021-07-31|Dato del contrato...| 6400|2021-07-31|2021-08-01|CT0001|
# +------------+----------+--------------------+-----+----------+----------+------+
# only showing top 10 rows
#
# Fin lectura partición: Sun Nov  6 18:32:40 2022
# Hecho en 6.2479 segundo(s)
# Tratando partición CT0002
# 80153
# +------------+----------+--------------------+-----+----------+----------+------+
# |        ctId|    fecRef|                dato|saldo|   fechIni|   fechFin|  proc|
# +------------+----------+--------------------+-----+----------+----------+------+
# |CT0002123782|2020-12-12|Dato del contrato...|14500|2020-12-12|2021-07-03|CT0002|
# |CT0002123782|2021-07-03|Dato del contrato...|20500|2021-07-03|2021-07-17|CT0002|
# |CT0002123782|2021-07-17|Dato del contrato...|16900|2021-07-17|2021-11-01|CT0002|
# |CT0002123782|2021-11-01|Dato del contrato...|62200|2021-11-01|2021-12-16|CT0002|
# |CT0002123782|2021-12-16|Dato del contrato...|62000|2021-12-16|2021-12-22|CT0002|
# |CT0002123782|2021-12-22|Dato del contrato...| 9400|2021-12-22|9999-12-31|CT0002|
# |CT0002123928|2020-04-26|Dato del contrato...| 7300|2020-04-26|2020-08-17|CT0002|
# |CT0002123928|2020-08-17|Dato del contrato...| 8400|2020-08-17|2020-12-16|CT0002|
# |CT0002123928|2020-12-16|Dato del contrato...| 9500|2020-12-16|2021-04-17|CT0002|
# |CT0002123928|2021-04-17|Dato del contrato...|74000|2021-04-17|2021-05-23|CT0002|
# +------------+----------+--------------------+-----+----------+----------+------+
# only showing top 10 rows
#
# Fin lectura partición: Sun Nov  6 18:32:40 2022
# Hecho en 0.8675 segundo(s)
# Tratando partición CT0003
# 79910
# +------------+----------+--------------------+-----+----------+----------+------+
# |        ctId|    fecRef|                dato|saldo|   fechIni|   fechFin|  proc|
# +------------+----------+--------------------+-----+----------+----------+------+
# |CT0003123587|2020-02-13|Dato del contrato...|49700|2020-02-13|2020-03-24|CT0003|
# |CT0003123587|2020-03-24|Dato del contrato...|13200|2020-03-24|2020-05-10|CT0003|
# |CT0003123587|2020-05-10|Dato del contrato...| 9500|2020-05-10|2020-08-10|CT0003|
# |CT0003123587|2020-08-10|Dato del contrato...|50100|2020-08-10|2021-03-08|CT0003|
# |CT0003123587|2021-03-08|Dato del contrato...|14100|2021-03-08|2021-04-25|CT0003|
# |CT0003123587|2021-04-25|Dato del contrato...|12800|2021-04-25|2021-04-27|CT0003|
# |CT0003123587|2021-04-27|Dato del contrato...| 8200|2021-04-27|2021-10-29|CT0003|
# |CT0003123587|2021-10-29|Dato del contrato...|34200|2021-10-29|9999-12-31|CT0003|
# |CT0003123593|2020-01-02|Dato del contrato...|22600|2020-01-02|2020-02-19|CT0003|
# |CT0003123593|2020-02-19|Dato del contrato...| 9500|2020-02-19|2020-05-20|CT0003|
# +------------+----------+--------------------+-----+----------+----------+------+
# only showing top 10 rows
#
# Fin lectura partición: Sun Nov  6 18:32:41 2022
# Hecho en 0.665 segundo(s)
# Tratando partición CT0004
# 79151
# +------------+----------+--------------------+-----+----------+----------+------+
# |        ctId|    fecRef|                dato|saldo|   fechIni|   fechFin|  proc|
# +------------+----------+--------------------+-----+----------+----------+------+
# |CT0004123527|2020-04-26|Dato del contrato...| 9200|2020-04-26|2020-05-07|CT0004|
# |CT0004123527|2020-05-07|Dato del contrato...| 9400|2020-05-07|2020-06-26|CT0004|
# |CT0004123527|2020-06-26|Dato del contrato...| 3500|2020-06-26|2020-06-28|CT0004|
# |CT0004123527|2020-06-28|Dato del contrato...|27000|2020-06-28|2020-08-28|CT0004|
# |CT0004123527|2020-08-28|Dato del contrato...|38300|2020-08-28|2020-09-06|CT0004|
# |CT0004123527|2020-09-06|Dato del contrato...| 1500|2020-09-06|2020-10-31|CT0004|
# |CT0004123527|2020-10-31|Dato del contrato...|29900|2020-10-31|2021-01-02|CT0004|
# |CT0004123527|2021-01-02|Dato del contrato...|11100|2021-01-02|2021-02-22|CT0004|
# |CT0004123527|2021-02-22|Dato del contrato...|21200|2021-02-22|2021-03-06|CT0004|
# |CT0004123527|2021-03-06|Dato del contrato...|21700|2021-03-06|2021-11-27|CT0004|
# +------------+----------+--------------------+-----+----------+----------+------+
# only showing top 10 rows
#
# Fin lectura partición: Sun Nov  6 18:32:42 2022
# Hecho en 0.5439 segundo(s)
# Tratando partición CT0005
# 80600
# +------------+----------+--------------------+-----+----------+----------+------+
# |        ctId|    fecRef|                dato|saldo|   fechIni|   fechFin|  proc|
# +------------+----------+--------------------+-----+----------+----------+------+
# |CT0005123796|2020-02-23|Dato del contrato...|37800|2020-02-23|2020-05-14|CT0005|
# |CT0005123796|2020-05-14|Dato del contrato...|39500|2020-05-14|2020-05-16|CT0005|
# |CT0005123796|2020-05-16|Dato del contrato...| 9700|2020-05-16|2020-09-28|CT0005|
# |CT0005123796|2020-09-28|Dato del contrato...|64800|2020-09-28|2021-04-05|CT0005|
# |CT0005123796|2021-04-05|Dato del contrato...| 3700|2021-04-05|2021-05-09|CT0005|
# |CT0005123796|2021-05-09|Dato del contrato...|31900|2021-05-09|9999-12-31|CT0005|
# |CT0005124295|2020-01-21|Dato del contrato...|18500|2020-01-21|2020-03-24|CT0005|
# |CT0005124295|2020-03-24|Dato del contrato...|24900|2020-03-24|2020-06-26|CT0005|
# |CT0005124295|2020-06-26|Dato del contrato...|11000|2020-06-26|2020-06-26|CT0005|
# |CT0005124295|2020-06-26|Dato del contrato...|21700|2020-06-26|2020-09-19|CT0005|
# +------------+----------+--------------------+-----+----------+----------+------+
# only showing top 10 rows
#
# Fin lectura partición: Sun Nov  6 18:32:42 2022
# Hecho en 0.4729 segundo(s)
# Tratando partición CT0006
# 80192
# +------------+----------+--------------------+-----+----------+----------+------+
# |        ctId|    fecRef|                dato|saldo|   fechIni|   fechFin|  proc|
# +------------+----------+--------------------+-----+----------+----------+------+
# |CT0006124073|2020-12-12|Dato del contrato...| 6900|2020-12-12|2021-05-16|CT0006|
# |CT0006124073|2021-05-16|Dato del contrato...|23400|2021-05-16|2021-07-14|CT0006|
# |CT0006124073|2021-07-14|Dato del contrato...|12500|2021-07-14|2021-10-25|CT0006|
# |CT0006124073|2021-10-25|Dato del contrato...|13000|2021-10-25|9999-12-31|CT0006|
# |CT0006124361|2021-09-14|Dato del contrato...|15900|2021-09-14|9999-12-31|CT0006|
# |CT0006124909|2020-02-16|Dato del contrato...| 5700|2020-02-16|2020-05-14|CT0006|
# |CT0006124909|2020-05-14|Dato del contrato...|49500|2020-05-14|2020-08-14|CT0006|
# |CT0006124909|2020-08-14|Dato del contrato...|81900|2020-08-14|2021-05-22|CT0006|
# |CT0006124909|2021-05-22|Dato del contrato...|53300|2021-05-22|2021-07-17|CT0006|
# |CT0006124909|2021-07-17|Dato del contrato...|17600|2021-07-17|9999-12-31|CT0006|
# +------------+----------+--------------------+-----+----------+----------+------+
# only showing top 10 rows
#
# Fin lectura partición: Sun Nov  6 18:32:43 2022
# Hecho en 0.3844 segundo(s)
# Tratando partición CT0007
# 79555
# +------------+----------+--------------------+-----+----------+----------+------+
# |        ctId|    fecRef|                dato|saldo|   fechIni|   fechFin|  proc|
# +------------+----------+--------------------+-----+----------+----------+------+
# |CT0007124825|2020-05-08|Dato del contrato...|13400|2020-05-08|2020-06-20|CT0007|
# |CT0007124825|2020-06-20|Dato del contrato...|62300|2020-06-20|2020-06-26|CT0007|
# |CT0007124825|2020-06-26|Dato del contrato...|12200|2020-06-26|2020-10-11|CT0007|
# |CT0007124825|2020-10-11|Dato del contrato...|36400|2020-10-11|2021-03-18|CT0007|
# |CT0007124825|2021-03-18|Dato del contrato...|38100|2021-03-18|2021-05-28|CT0007|
# |CT0007124825|2021-05-28|Dato del contrato...| 8500|2021-05-28|2021-10-12|CT0007|
# |CT0007124825|2021-10-12|Dato del contrato...|32100|2021-10-12|2021-11-04|CT0007|
# |CT0007124825|2021-11-04|Dato del contrato...|24800|2021-11-04|2021-11-22|CT0007|
# |CT0007124825|2021-11-22|Dato del contrato...|17300|2021-11-22|2021-12-05|CT0007|
# |CT0007124825|2021-12-05|Dato del contrato...|24600|2021-12-05|9999-12-31|CT0007|
# +------------+----------+--------------------+-----+----------+----------+------+
# only showing top 10 rows
#
# Fin lectura partición: Sun Nov  6 18:32:43 2022
# Hecho en 0.3059 segundo(s)
# Tratando partición CT0008
# 79725
# +------------+----------+--------------------+-----+----------+----------+------+
# |        ctId|    fecRef|                dato|saldo|   fechIni|   fechFin|  proc|
# +------------+----------+--------------------+-----+----------+----------+------+
# |CT0008123808|2020-03-12|Dato del contrato...| 7700|2020-03-12|2020-04-27|CT0008|
# |CT0008123808|2020-04-27|Dato del contrato...|25100|2020-04-27|2020-07-20|CT0008|
# |CT0008123808|2020-07-20|Dato del contrato...|14700|2020-07-20|2020-08-16|CT0008|
# |CT0008123808|2020-08-16|Dato del contrato...|52800|2020-08-16|2020-11-06|CT0008|
# |CT0008123808|2020-11-06|Dato del contrato...|20000|2020-11-06|2020-11-25|CT0008|
# |CT0008123808|2020-11-25|Dato del contrato...|47600|2020-11-25|2021-02-22|CT0008|
# |CT0008123808|2021-02-22|Dato del contrato...|65900|2021-02-22|2021-03-17|CT0008|
# |CT0008123808|2021-03-17|Dato del contrato...|56000|2021-03-17|2021-03-30|CT0008|
# |CT0008123808|2021-03-30|Dato del contrato...|14200|2021-03-30|2021-04-21|CT0008|
# |CT0008123808|2021-04-21|Dato del contrato...|45000|2021-04-21|2021-06-15|CT0008|
# +------------+----------+--------------------+-----+----------+----------+------+
# only showing top 10 rows
#
# Fin lectura partición: Sun Nov  6 18:32:43 2022
# Hecho en 0.2838 segundo(s)
# Tratando partición CT0009
# 79671
# +------------+----------+--------------------+-----+----------+----------+------+
# |        ctId|    fecRef|                dato|saldo|   fechIni|   fechFin|  proc|
# +------------+----------+--------------------+-----+----------+----------+------+
# |CT0009123542|2021-10-04|Dato del contrato...|37400|2021-10-04|9999-12-31|CT0009|
# |CT0009124221|2020-04-02|Dato del contrato...|60800|2020-04-02|2020-05-22|CT0009|
# |CT0009124221|2020-05-22|Dato del contrato...| 2400|2020-05-22|2020-07-31|CT0009|
# |CT0009124221|2020-07-31|Dato del contrato...|36900|2020-07-31|2021-05-06|CT0009|
# |CT0009124221|2021-05-06|Dato del contrato...| 4300|2021-05-06|2021-11-23|CT0009|
# |CT0009124221|2021-11-23|Dato del contrato...|44200|2021-11-23|2021-12-24|CT0009|
# |CT0009124221|2021-12-24|Dato del contrato...|87500|2021-12-24|9999-12-31|CT0009|
# |CT0009124479|2020-01-28|Dato del contrato...| 9400|2020-01-28|2020-09-01|CT0009|
# |CT0009124479|2020-09-01|Dato del contrato...|13700|2020-09-01|2021-01-11|CT0009|
# |CT0009124479|2021-01-11|Dato del contrato...|14600|2021-01-11|2021-03-19|CT0009|
# +------------+----------+--------------------+-----+----------+----------+------+
# only showing top 10 rows
#
# Fin lectura partición: Sun Nov  6 18:32:43 2022
# Hecho en 0.2465 segundo(s)
# Tratando partición CT0010
# 79529
# +------------+----------+--------------------+-----+----------+----------+------+
# |        ctId|    fecRef|                dato|saldo|   fechIni|   fechFin|  proc|
# +------------+----------+--------------------+-----+----------+----------+------+
# |CT0010124154|2020-03-24|Dato del contrato...|37900|2020-03-24|2020-06-12|CT0010|
# |CT0010124154|2020-06-12|Dato del contrato...|10300|2020-06-12|2020-09-11|CT0010|
# |CT0010124154|2020-09-11|Dato del contrato...|40000|2020-09-11|2020-10-21|CT0010|
# |CT0010124154|2020-10-21|Dato del contrato...|36100|2020-10-21|2020-10-24|CT0010|
# |CT0010124154|2020-10-24|Dato del contrato...|61900|2020-10-24|2021-04-11|CT0010|
# |CT0010124154|2021-04-11|Dato del contrato...| 3600|2021-04-11|2021-04-27|CT0010|
# |CT0010124154|2021-04-27|Dato del contrato...| 2300|2021-04-27|2021-07-18|CT0010|
# |CT0010124154|2021-07-18|Dato del contrato...|33200|2021-07-18|2021-07-30|CT0010|
# |CT0010124154|2021-07-30|Dato del contrato...|30900|2021-07-30|2021-11-13|CT0010|
# |CT0010124154|2021-11-13|Dato del contrato...|42300|2021-11-13|9999-12-31|CT0010|
# +------------+----------+--------------------+-----+----------+----------+------+
# only showing top 10 rows
#
# Fin lectura partición: Sun Nov  6 18:32:44 2022
# Hecho en 0.2326 segundo(s)
# Tratando partición CT0011
# 79683
# +------------+----------+--------------------+-----+----------+----------+------+
# |        ctId|    fecRef|                dato|saldo|   fechIni|   fechFin|  proc|
# +------------+----------+--------------------+-----+----------+----------+------+
# |CT0011123535|2020-01-21|Dato del contrato...|29700|2020-01-21|2020-01-24|CT0011|
# |CT0011123535|2020-01-24|Dato del contrato...| 4200|2020-01-24|2020-02-22|CT0011|
# |CT0011123535|2020-02-22|Dato del contrato...| 5600|2020-02-22|2020-04-06|CT0011|
# |CT0011123535|2020-04-06|Dato del contrato...| 9300|2020-04-06|2020-05-11|CT0011|
# |CT0011123535|2020-05-11|Dato del contrato...|45600|2020-05-11|2020-05-17|CT0011|
# |CT0011123535|2020-05-17|Dato del contrato...|16100|2020-05-17|2020-06-15|CT0011|
# |CT0011123535|2020-06-15|Dato del contrato...|29800|2020-06-15|2021-01-05|CT0011|
# |CT0011123535|2021-01-05|Dato del contrato...|11400|2021-01-05|2021-01-20|CT0011|
# |CT0011123535|2021-01-20|Dato del contrato...|11500|2021-01-20|2021-03-19|CT0011|
# |CT0011123535|2021-03-19|Dato del contrato...|25700|2021-03-19|2021-04-22|CT0011|
# +------------+----------+--------------------+-----+----------+----------+------+
# only showing top 10 rows
#
# Fin lectura partición: Sun Nov  6 18:32:44 2022
# Hecho en 0.269 segundo(s)
# Tratando partición CT0012
# 79360
# +------------+----------+--------------------+-----+----------+----------+------+
# |        ctId|    fecRef|                dato|saldo|   fechIni|   fechFin|  proc|
# +------------+----------+--------------------+-----+----------+----------+------+
# |CT0012124700|2020-01-01|Dato del contrato...|60100|2020-01-01|2020-03-11|CT0012|
# |CT0012124700|2020-03-11|Dato del contrato...| 2500|2020-03-11|2020-10-26|CT0012|
# |CT0012124700|2020-10-26|Dato del contrato...| 8300|2020-10-26|2020-10-29|CT0012|
# |CT0012124700|2020-10-29|Dato del contrato...| 7400|2020-10-29|2020-11-02|CT0012|
# |CT0012124700|2020-11-02|Dato del contrato...|46300|2020-11-02|2020-11-11|CT0012|
# |CT0012124700|2020-11-11|Dato del contrato...|69800|2020-11-11|2021-03-22|CT0012|
# |CT0012124700|2021-03-22|Dato del contrato...|21900|2021-03-22|2021-06-23|CT0012|
# |CT0012124700|2021-06-23|Dato del contrato...|35800|2021-06-23|2021-07-24|CT0012|
# |CT0012124700|2021-07-24|Dato del contrato...|65500|2021-07-24|2021-12-10|CT0012|
# |CT0012124700|2021-12-10|Dato del contrato...| 6900|2021-12-10|9999-12-31|CT0012|
# +------------+----------+--------------------+-----+----------+----------+------+
# only showing top 10 rows
#
# Fin lectura partición: Sun Nov  6 18:32:44 2022
# Hecho en 0.193 segundo(s)
# Tratando partición CT0013
# 80052
# +------------+----------+--------------------+-----+----------+----------+------+
# |        ctId|    fecRef|                dato|saldo|   fechIni|   fechFin|  proc|
# +------------+----------+--------------------+-----+----------+----------+------+
# |CT0013124199|2020-02-26|Dato del contrato...|50500|2020-02-26|2020-05-27|CT0013|
# |CT0013124199|2020-05-27|Dato del contrato...|33200|2020-05-27|2020-07-27|CT0013|
# |CT0013124199|2020-07-27|Dato del contrato...|13000|2020-07-27|2021-01-06|CT0013|
# |CT0013124199|2021-01-06|Dato del contrato...|23800|2021-01-06|2021-04-02|CT0013|
# |CT0013124199|2021-04-02|Dato del contrato...|47200|2021-04-02|2021-08-19|CT0013|
# |CT0013124199|2021-08-19|Dato del contrato...|40700|2021-08-19|2021-08-26|CT0013|
# |CT0013124199|2021-08-26|Dato del contrato...|16400|2021-08-26|2021-11-06|CT0013|
# |CT0013124199|2021-11-06|Dato del contrato...|14000|2021-11-06|2021-11-22|CT0013|
# |CT0013124199|2021-11-22|Dato del contrato...|25100|2021-11-22|9999-12-31|CT0013|
# |CT0013124332|2020-01-11|Dato del contrato...|14700|2020-01-11|2020-07-14|CT0013|
# +------------+----------+--------------------+-----+----------+----------+------+
# only showing top 10 rows
#
# Fin lectura partición: Sun Nov  6 18:32:44 2022
# Hecho en 0.2712 segundo(s)
# Tratando partición CT0014
# 80272
# +------------+----------+--------------------+-----+----------+----------+------+
# |        ctId|    fecRef|                dato|saldo|   fechIni|   fechFin|  proc|
# +------------+----------+--------------------+-----+----------+----------+------+
# |CT0014123710|2021-01-09|Dato del contrato...| 5000|2021-01-09|2021-01-21|CT0014|
# |CT0014123710|2021-01-21|Dato del contrato...| 3400|2021-01-21|9999-12-31|CT0014|
# |CT0014124061|2020-04-05|Dato del contrato...|11700|2020-04-05|2020-07-07|CT0014|
# |CT0014124061|2020-07-07|Dato del contrato...|32500|2020-07-07|2020-08-09|CT0014|
# |CT0014124061|2020-08-09|Dato del contrato...|16600|2020-08-09|2020-11-01|CT0014|
# |CT0014124061|2020-11-01|Dato del contrato...| 8600|2020-11-01|2020-12-13|CT0014|
# |CT0014124061|2020-12-13|Dato del contrato...| 9500|2020-12-13|2021-01-16|CT0014|
# |CT0014124061|2021-01-16|Dato del contrato...|16600|2021-01-16|2021-02-06|CT0014|
# |CT0014124061|2021-02-06|Dato del contrato...|28100|2021-02-06|2021-02-10|CT0014|
# |CT0014124061|2021-02-10|Dato del contrato...|10700|2021-02-10|2021-02-27|CT0014|
# +------------+----------+--------------------+-----+----------+----------+------+
# only showing top 10 rows
#
# Fin lectura partición: Sun Nov  6 18:32:45 2022
# Hecho en 0.2063 segundo(s)
# Tratando partición CT0015
# 79928
# +------------+----------+--------------------+-----+----------+----------+------+
# |        ctId|    fecRef|                dato|saldo|   fechIni|   fechFin|  proc|
# +------------+----------+--------------------+-----+----------+----------+------+
# |CT0015123773|2020-02-14|Dato del contrato...| 4700|2020-02-14|2020-07-25|CT0015|
# |CT0015123773|2020-07-25|Dato del contrato...|35200|2020-07-25|2020-10-04|CT0015|
# |CT0015123773|2020-10-04|Dato del contrato...|28900|2020-10-04|2021-08-20|CT0015|
# |CT0015123773|2021-08-20|Dato del contrato...| 4700|2021-08-20|9999-12-31|CT0015|
# |CT0015124952|2020-11-02|Dato del contrato...| 7700|2020-11-02|2021-01-23|CT0015|
# |CT0015124952|2021-01-23|Dato del contrato...|72300|2021-01-23|9999-12-31|CT0015|
# |CT0015125323|2020-03-06|Dato del contrato...| 5200|2020-03-06|2020-04-11|CT0015|
# |CT0015125323|2020-04-11|Dato del contrato...| 7400|2020-04-11|2020-07-14|CT0015|
# |CT0015125323|2020-07-14|Dato del contrato...| 7800|2020-07-14|2021-04-18|CT0015|
# |CT0015125323|2021-04-18|Dato del contrato...| 8400|2021-04-18|2021-04-26|CT0015|
# +------------+----------+--------------------+-----+----------+----------+------+
# only showing top 10 rows
#
# Fin lectura partición: Sun Nov  6 18:32:45 2022
# Hecho en 0.2639 segundo(s)
# TOTAL hecho en 11.4782 segundo(s)

# %%
# Lectura del DF original

# %%
esquema = StructType() \
      .add("ctId",StringType(),True) \
      .add("fecRef",StringType(),True) \
      .add("dato",StringType(),True) \
      .add("saldo",IntegerType(),True) \
      .add("proc",StringType(),True)

for i in range(1, 16):
    inicioP = time.perf_counter()
    if i < 10: proc = 'CT000'+str(i)
    else:      proc = 'CT00'+str(i)

    print ('Tratando partición '+proc)
    
    df = spark.read.option("mergeSchema", True).option("schema", "esquema").option("basePath", "file:///opt/workspace/datos/fakeContractsSinFechas.parquet/")\
               .format("parquet").load(['./datos/fakeContractsSinFechas.parquet/proc='+proc])    
    
    if i == 1:df.printSchema()
    print(df.count())
    df.show(1)
    print ('Fin lectura partición: '+time.strftime("%c"))
    final = time.perf_counter()
    print(f'Hecho en {round(final - inicioP, 4)} segundo(s)')

final = time.perf_counter()
print(f'TOTAL hecho en {round(final - inicio, 4)} segundo(s)')
# Out:
# Tratando partición CT0001
# root
#  |-- ctId: string (nullable = true)
#  |-- fecRef: string (nullable = true)
#  |-- dato: string (nullable = true)
#  |-- saldo: integer (nullable = true)
#  |-- proc: string (nullable = true)
#
# 79285
# +------------+----------+--------------------+-----+------+
# |        ctId|    fecRef|                dato|saldo|  proc|
# +------------+----------+--------------------+-----+------+
# |CT0001123484|2021-06-21|Dato del contrato...|47900|CT0001|
# +------------+----------+--------------------+-----+------+
# only showing top 1 row
#
# Fin lectura partición: Sun Nov  6 18:32:45 2022
# Hecho en 0.2455 segundo(s)
# Tratando partición CT0002
# 80153
# +------------+----------+--------------------+-----+------+
# |        ctId|    fecRef|                dato|saldo|  proc|
# +------------+----------+--------------------+-----+------+
# |CT0002375319|2021-05-25|Dato del contrato...| 3100|CT0002|
# +------------+----------+--------------------+-----+------+
# only showing top 1 row
#
# Fin lectura partición: Sun Nov  6 18:32:45 2022
# Hecho en 0.1913 segundo(s)
# Tratando partición CT0003
# 79910
# +------------+----------+--------------------+-----+------+
# |        ctId|    fecRef|                dato|saldo|  proc|
# +------------+----------+--------------------+-----+------+
# |CT0003212981|2020-10-25|Dato del contrato...|16200|CT0003|
# +------------+----------+--------------------+-----+------+
# only showing top 1 row
#
# Fin lectura partición: Sun Nov  6 18:32:45 2022
# Hecho en 0.2021 segundo(s)
# Tratando partición CT0004
# 79151
# +------------+----------+--------------------+-----+------+
# |        ctId|    fecRef|                dato|saldo|  proc|
# +------------+----------+--------------------+-----+------+
# |CT0004123462|2020-12-01|Dato del contrato...|14200|CT0004|
# +------------+----------+--------------------+-----+------+
# only showing top 1 row
#
# Fin lectura partición: Sun Nov  6 18:32:46 2022
# Hecho en 0.3395 segundo(s)
# Tratando partición CT0005
# 80600
# +------------+----------+--------------------+-----+------+
# |        ctId|    fecRef|                dato|saldo|  proc|
# +------------+----------+--------------------+-----+------+
# |CT0005123475|2021-01-15|Dato del contrato...| 9000|CT0005|
# +------------+----------+--------------------+-----+------+
# only showing top 1 row
#
# Fin lectura partición: Sun Nov  6 18:32:46 2022
# Hecho en 0.2275 segundo(s)
# Tratando partición CT0006
# 80192
# +------------+----------+--------------------+-----+------+
# |        ctId|    fecRef|                dato|saldo|  proc|
# +------------+----------+--------------------+-----+------+
# |CT0006344420|2020-10-26|Dato del contrato...|13600|CT0006|
# +------------+----------+--------------------+-----+------+
# only showing top 1 row
#
# Fin lectura partición: Sun Nov  6 18:32:46 2022
# Hecho en 0.204 segundo(s)
# Tratando partición CT0007
# 79555
# +------------+----------+--------------------+-----+------+
# |        ctId|    fecRef|                dato|saldo|  proc|
# +------------+----------+--------------------+-----+------+
# |CT0007249738|2020-08-27|Dato del contrato...|33700|CT0007|
# +------------+----------+--------------------+-----+------+
# only showing top 1 row
#
# Fin lectura partición: Sun Nov  6 18:32:46 2022
# Hecho en 0.1953 segundo(s)
# Tratando partición CT0008
# 79725
# +------------+----------+--------------------+-----+------+
# |        ctId|    fecRef|                dato|saldo|  proc|
# +------------+----------+--------------------+-----+------+
# |CT0008180372|2021-05-18|Dato del contrato...| 4600|CT0008|
# +------------+----------+--------------------+-----+------+
# only showing top 1 row
#
# Fin lectura partición: Sun Nov  6 18:32:47 2022
# Hecho en 0.2094 segundo(s)
# Tratando partición CT0009
# 79671
# +------------+----------+--------------------+-----+------+
# |        ctId|    fecRef|                dato|saldo|  proc|
# +------------+----------+--------------------+-----+------+
# |CT0009287744|2021-12-07|Dato del contrato...|79400|CT0009|
# +------------+----------+--------------------+-----+------+
# only showing top 1 row
#
# Fin lectura partición: Sun Nov  6 18:32:47 2022
# Hecho en 0.1829 segundo(s)
# Tratando partición CT0010
# 79529
# +------------+----------+--------------------+-----+------+
# |        ctId|    fecRef|                dato|saldo|  proc|
# +------------+----------+--------------------+-----+------+
# |CT0010270569|2021-03-01|Dato del contrato...|21500|CT0010|
# +------------+----------+--------------------+-----+------+
# only showing top 1 row
#
# Fin lectura partición: Sun Nov  6 18:32:47 2022
# Hecho en 0.1596 segundo(s)
# Tratando partición CT0011
# 79683
# +------------+----------+--------------------+-----+------+
# |        ctId|    fecRef|                dato|saldo|  proc|
# +------------+----------+--------------------+-----+------+
# |CT0011251138|2021-03-16|Dato del contrato...|45500|CT0011|
# +------------+----------+--------------------+-----+------+
# only showing top 1 row
#
# Fin lectura partición: Sun Nov  6 18:32:47 2022
# Hecho en 0.1633 segundo(s)
# Tratando partición CT0012
# 79360
# +------------+----------+--------------------+-----+------+
# |        ctId|    fecRef|                dato|saldo|  proc|
# +------------+----------+--------------------+-----+------+
# |CT0012326633|2021-03-31|Dato del contrato...|49000|CT0012|
# +------------+----------+--------------------+-----+------+
# only showing top 1 row
#
# Fin lectura partición: Sun Nov  6 18:32:47 2022
# Hecho en 0.2012 segundo(s)
# Tratando partición CT0013
# 80052
# +------------+----------+--------------------+-----+------+
# |        ctId|    fecRef|                dato|saldo|  proc|
# +------------+----------+--------------------+-----+------+
# |CT0013338174|2021-09-19|Dato del contrato...| 5400|CT0013|
# +------------+----------+--------------------+-----+------+
# only showing top 1 row
#
# Fin lectura partición: Sun Nov  6 18:32:48 2022
# Hecho en 0.2676 segundo(s)
# Tratando partición CT0014
# 80272
# +------------+----------+--------------------+-----+------+
# |        ctId|    fecRef|                dato|saldo|  proc|
# +------------+----------+--------------------+-----+------+
# |CT0014369367|2020-06-21|Dato del contrato...|10500|CT0014|
# +------------+----------+--------------------+-----+------+
# only showing top 1 row
#
# Fin lectura partición: Sun Nov  6 18:32:48 2022
# Hecho en 0.1496 segundo(s)
# Tratando partición CT0015
# 79928
# +------------+----------+--------------------+-----+------+
# |        ctId|    fecRef|                dato|saldo|  proc|
# +------------+----------+--------------------+-----+------+
# |CT0015371502|2020-08-31|Dato del contrato...|10800|CT0015|
# +------------+----------+--------------------+-----+------+
# only showing top 1 row
#
# Fin lectura partición: Sun Nov  6 18:32:48 2022
# Hecho en 0.151 segundo(s)
# TOTAL hecho en 14.5916 segundo(s)

# %%
spark.sparkContext.stop()
print('Sacabao')
# Out:
# Sacabao
